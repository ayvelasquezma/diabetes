# %% [markdown]
# ## Evaluacion
#
# Usando los modelos con los mejores hiperparametros se hara el calculo de metricas de desempeño para esto calcularemos las predicciones con el conjunto de pruebas por cada modelo

# %%
y_pred_svc=grid_svc.predict(X_test)

# %%
y_pred_knn=grid_knn.predict(X_test)

# %% [markdown]
# Con la matriz de confusion podremos saber que tantos aciertos tuvo cada modelo

# %%
cnf_matrix_svc = confusion_matrix(y_test, y_pred_svc)
cnf_matrix_svc
# Out:
# array([[70,  9],
#        [15, 24]])

# %%
cnf_matrix_knn = confusion_matrix(y_test, y_pred_knn)
cnf_matrix_knn
# Out:
# array([[66, 13],
#        [17, 22]])

# %% [markdown]
# Con el la prediccion de los modelos y las etiquetas correspondientes al conjunto de prueba podemos hacer el calculo de las 4 medidas mas conocidas: Exactitud, precision, recall y f1 score

# %%
print(f'Exactitud: {accuracy_score(y_test, y_pred_svc):.4f}')
print(f'Precisión: {precision_score(y_test, y_pred_svc):.4f}')
print(f'Recall:    {recall_score(y_test, y_pred_svc):.4f}')
print(f'F_1 score: {f1_score(y_test, y_pred_svc):.4f}')
# Out:
# Exactitud: 0.7966
# Precisión: 0.7273
# Recall:    0.6154
# F_1 score: 0.6667

# %%
print(f'Exactitud: {accuracy_score(y_test, y_pred_knn):.4f}')
print(f'Precisión: {precision_score(y_test, y_pred_knn):.4f}')
print(f'Recall:    {recall_score(y_test, y_pred_knn):.4f}')
print(f'F_1 score: {f1_score(y_test, y_pred_knn):.4f}')
# Out:
# Exactitud: 0.7458
# Precisión: 0.6286
# Recall:    0.5641
# F_1 score: 0.5946
