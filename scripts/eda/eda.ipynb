# %% [markdown]
# #**Estadistica descriptiva**

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   392 non-null    float64
#  1   BloodPressure             392 non-null    float64
#  2   SkinThickness             392 non-null    float64
#  3   Insulin                   392 non-null    float64
#  4   BMI                       392 non-null    float64
#  5   DiabetesPedigreeFunction  392 non-null    float64
#  6   Age                       392 non-null    int64
#  7   Pregnancies               392 non-null    int64
#  8   Outcome                   392 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 27.7 KB

# %%
diabetes.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  392.000000     392.000000     392.000000  392.000000  392.000000
# mean   122.627551      70.663265      29.145408  156.056122   33.086224
# std     30.860781      12.496092      10.516424  118.841690    7.027659
# min     56.000000      24.000000       7.000000   14.000000   18.200000
# 25%     99.000000      62.000000      21.000000   76.750000   28.400000
# 50%    119.000000      70.000000      29.000000  125.500000   33.200000
# 75%    143.000000      78.000000      37.000000  190.000000   37.100000
# max    198.000000     110.000000      63.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age  Pregnancies     Outcome
# count                392.000000  392.000000   392.000000  392.000000
# mean                   0.523046   30.864796     3.301020    0.331633
# std                    0.345488   10.200777     3.211424    0.471401
# ...

# %%
renaming={'Glucose':'Glucosa',
          'BloodPressure':'Presion_Sanguinea',
          'SkinThickness':'Grosor_Tricep',
          'Insulin':'Insulina',
          'BMI':'IMC',
          'DiabetesPedigreeFunction':'Prob_Diabetes',
          'Age':'Edad',
          'Pregnancies':'Embarazos',
          'Outcome':'Diabetico' }
diabetes.rename(columns=renaming, inplace=True)

# %%
diabetes.head()
# Out:
#    Glucosa  Presion_Sanguinea  Grosor_Tricep  Insulina   IMC  Prob_Diabetes  \
# 0     89.0               66.0           23.0      94.0  28.1          0.167
# 1    137.0               40.0           35.0     168.0  43.1          2.288
# 2     78.0               50.0           32.0      88.0  31.0          0.248
# 3    197.0               70.0           45.0     543.0  30.5          0.158
# 4    189.0               60.0           23.0     846.0  30.1          0.398
#
#    Edad  Embarazos  Diabetico
# 0    21          1          0
# 1    33          0          1
# 2    26          3          1
# 3    53          2          1
# 4    59          1          1

# %%
diabetes['Diabetico'].value_counts()
# Out:
# 0    262
# 1    130
# Name: Diabetico, dtype: int64

# %%
matriz_correlacion=diabetes.corr()
matriz_correlacion
# Out:
#                     Glucosa  Presion_Sanguinea  Grosor_Tricep  Insulina  \
# Glucosa            1.000000           0.210027       0.198856  0.581223
# Presion_Sanguinea  0.210027           1.000000       0.232571  0.098512
# Grosor_Tricep      0.198856           0.232571       1.000000  0.182199
# Insulina           0.581223           0.098512       0.182199  1.000000
# IMC                0.209516           0.304403       0.664355  0.226397
# Prob_Diabetes      0.140180          -0.015971       0.160499  0.135906
# Edad               0.343641           0.300039       0.167761  0.217082
# Embarazos          0.198291           0.213355       0.093209  0.078984
# Diabetico          0.515703           0.192673       0.255936  0.301429
#
#                         IMC  Prob_Diabetes      Edad  Embarazos  Diabetico
# Glucosa            0.209516       0.140180  0.343641   0.198291   0.515703
# Presion_Sanguinea  0.304403      -0.015971  0.300039   0.213355   0.192673
# ...

# %% [markdown]
# #**Visualizacion de datos**

# %%
g = sns.PairGrid(diabetes, hue="Diabetico", palette='rainbow');
g.map(plt.scatter);

# %%
sns.heatmap(matriz_correlacion, annot=True, fmt=".2f", cmap='Blues', annot_kws = {'size':8});

# %%
matriz_correlacion['Glucosa'].sort_values(ascending=False)[1:]
# Out:
# Insulina             0.581223
# Diabetico            0.515703
# Edad                 0.343641
# Presion_Sanguinea    0.210027
# IMC                  0.209516
# Grosor_Tricep        0.198856
# Embarazos            0.198291
# Prob_Diabetes        0.140180
# Name: Glucosa, dtype: float64

# %%
diabetes_correlaciones=diabetes.copy()

# %%
pd.options.plotting.backend = "plotly"

# %%
diabetes[['Diabetico', 'Insulina']].plot(kind='box', color='Diabetico')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
diabetes[['Diabetico', 'Glucosa']].plot(kind='box', color='Diabetico')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
diabetes[['Diabetico', 'Embarazos']].plot(kind='box', color='Diabetico')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
